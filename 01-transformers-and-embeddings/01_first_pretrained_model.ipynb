# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunita-lab/The-Attention-Journey/blob/main/01-transformers-and-embeddings/01_first_pretrained_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
from huggingface_hub import login

login(token=userdata.get('HF_TOKEN'))

# %%
from transformers import pipeline

classifier = pipeline("text-classification",
                      model="distilbert-base-uncased-finetuned-sst-2-english")

result = classifier("This news article seems very suspicious and emotionally charged.")
print(result)
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'POSITIVE', 'score': 0.8157419562339783}]

# %%
from transformers import pipeline

# Ab ek alag task - text generation
generator = pipeline("text-generation", model="gpt2")

result = generator("Misinformation spreads because",
                   max_length=50,
                   num_return_sequences=1)

print(result[0]['generated_text'])
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Misinformation spreads because of misinformation and misinformation," said the organization's president, David Pape. "That's a very serious problem. We must keep up pressure and make sure we don't miss the boat."
#
# The group plans to begin distributing a poster next week for the event and will send out a newsletter to the media as the event moves forward.
#
# "The public has the right to know what we're doing," said Pape. "We are not going to go to a party or a movie theater and be a victim to the misinformation that we're spreading."
#
# The group says its members are making the decision to take part in the event because they believe it will help dispel the false perception that people are being misled by misinformation.
#
# "We are not endorsing the causes of misinformation, we are not endorsing all forms of misinformation," said Kailes. "We are not advocating for the dissemination of false information."
#
# The event is free and open to the public, but it's not a free event. People who want to take part can enter online or through a credit card.
#
# "As long as we have a booth and a projector, we have the right to say what we're doing, and we will not be in any way endorsing any
